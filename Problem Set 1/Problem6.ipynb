# %% [markdown]
# Question 6 - On a given day (average basis), a student is observed to spend 33% of time in studying, 30% in
# sleeping, 18% in playing, 5% for hobby activities, and rest for spending with friends and family.
# Plot a pie chart showing his daily activities.

# %%
import matplotlib.pyplot as plt

# %%
Activities = ["Studying", "Sleeping", "Playing", "Hobbies", "Family"]
Time_Distribution = [33, 30, 18, 5, 14]
Figure = plt.figure(figsize =(10, 7))
plt.pie(Time_Distribution, labels = Activities, colors=["red", "blue", "green", "purple", "yellow"])
plt.show()
