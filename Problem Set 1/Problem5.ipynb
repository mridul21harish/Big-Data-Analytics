# %% [markdown]
# Question 5 - In Analytics and Systems of Bigdata course, for a class of 100 students, around 31 students
# secured ‘S’ grade, 29 secured ‘B’ grade, 25 ‘C’ grades, and rest of them secured ‘D’ grades. If
# the range of each grade is 15 marks. (S for 85 to 100 marks, A for 70 to 85 …). Develop an
# application that represents the above data: using Pie and Bar graphs.

# %%
import matplotlib.pyplot as plt

# %%
Grades = ["S", "B", "C", "D"]
Students = [31, 29, 25, 15]
Figure = plt.figure(figsize =(10, 7))
plt.pie(Students, labels = Grades, colors=["red", "blue", "green", "purple"])
plt.show()

# %%
plt.bar(Grades, Students, color = ["red", "blue", "green", "purple"])
plt.xlabel("Grades")
plt.ylabel("Number of Students")
plt.show()
